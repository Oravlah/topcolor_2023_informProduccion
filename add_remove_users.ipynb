# %%
import users_mgt as um
# Out:
# Python-dotenv could not parse statement starting at line 1
# Engine(mysql+pymysql://visita_test:***@10.6.0.7:3306/topcolor)

# %%
um.create_user_table()
# Out:
# 2023-07-24 23:43:48,491 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2023-07-24 23:43:48,492 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-07-24 23:43:49,288 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2023-07-24 23:43:49,288 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-07-24 23:43:49,711 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2023-07-24 23:43:49,712 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-07-24 23:43:50,579 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-24 23:43:50,583 INFO sqlalchemy.engine.Engine DESCRIBE `topcolor`.`user`
# 2023-07-24 23:43:50,585 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-07-24 23:43:50,852 INFO sqlalchemy.engine.Engine COMMIT

# %%
#um.add_user('test','test1','test@test.com')
#um.add_user('topcolor','123','test2@test.com')
um.add_user('borisB','a12B#','test2@test.com')
# Out:
# 2023-07-24 23:45:47,432 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-24 23:45:47,436 INFO sqlalchemy.engine.Engine INSERT INTO user (username, email, password) VALUES (%(username)s, %(email)s, %(password)s)
# 2023-07-24 23:45:47,437 INFO sqlalchemy.engine.Engine [cached since 77.13s ago] {'username': 'borisB', 'email': 'test2@test.com', 'password': 'sha256$aeBM2OxXRbMnvDNq$d3d23714fb2b897884d5e22ec7bdc8251a2b8e05d8dc1324a2eb8ff73d1b18e9'}
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/envs/topcolor_2023_informProduccion2/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1968, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967     if not evt_handled:
# -> 1968         self.dialect.do_execute(
#    1969             cursor, str_statement, effective_parameters, context
#    1970         )
# ...

# %%
um.show_users()
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 um.show_users()
#
# File ~/PycharmProjects/topcolor_2023_informProduccion/users_mgt.py:44, in show_users()
#      43 def show_users():
# ---> 44     select_st = select([User_tbl.c.username, User_tbl.c.email])
#      46     conn = engine.connect()
#      47     rs = conn.execute(select_st)
#
# File ~/anaconda3/envs/topcolor_2023_informProduccion/lib/python3.8/site-packages/sqlalchemy/sql/_selectable_constructors.py:493, in select(*entities, **__kw)
#     491 if __kw:
#     492     raise _no_kw()
# --> 493 return Select(*entities)
#
# File ~/anaconda3/envs/topcolor_2023_informProduccion/lib/python3.8/site-packages/sqlalchemy/sql/selectable.py:5161, in Select.__init__(self, *entities)
#    5154 def __init__(self, *entities: _ColumnsClauseArgument[Any]):
# ...

# %%
um.del_user('mariaisabel')
